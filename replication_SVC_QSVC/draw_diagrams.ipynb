# %%
import matplotlib.pyplot as plt

# Sample data
x_values = ['chunk-1', 'chunk-2', 'chunk-3', 'chunk-4', 'chunk-5', 'chunk-6', 'chunk-7', 'chunk-8', 'chunk-9', 'chunk-10']
train_time = [441.57, 389.86, 394.86, 387.53, 392.2, 383.86, 386.87, 388.31, 381.26, 390.91]
test1_time = [10632.2, 9460.8, 9519.0, 9510.6, 9483.0, 9504.6, 9464.2, 9478.0, 9486.0, 9428.4]
test2_time = [419.484, 419.918, 418.574, 420.222, 428.988, 421.052, 423.084, 421.28, 420.674, 420.674]

# Plotting the line graph
plt.plot(x_values, train_time, marker='o', linestyle='-', label='Training Time (Chunk Size: 500)')
plt.plot(x_values, test1_time, marker='o', linestyle='-', label='Testing Time/20 (All@Once: 1721 Sample)')
plt.plot(x_values, test2_time, marker='o', linestyle='-', label='Testing Time/5 (One@One: 1721 Sample)')

# Adding labels and title
plt.xlabel('Chunk Models')
plt.ylabel('Time in Seconds')
plt.title('')

# Displaying the graph
plt.grid(True, alpha=0.5)  # Adding grid
plt.xticks(rotation=30)
plt.legend()
plt.savefig(f'inc_saved_images/comp_train_test.png') #Save the image to disk
plt.show()

# %%
test1_time = [531.61, 473.04, 475.95, 475.53, 474.15, 475.23, 473.21, 473.90, 474.30, 471.42]
test2_time = [419.484, 419.918, 418.574, 420.222, 428.988, 421.052, 423.084, 421.28, 420.674, 420.674]

for t in test1_time:
    print(f"{round(t*20, 2)}", end=', ')
# Out:
# 10632.2, 9460.8, 9519.0, 9510.6, 9483.0, 9504.6, 9464.2, 9478.0, 9486.0, 9428.4,

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from the table
chunks = ['Chunk-1', 'Chunk-2', 'Chunk-3', 'Chunk-4', 'Chunk-5', 'Chunk-6', 'Chunk-7', 'Chunk-8', 'Chunk-9', 'Chunk-10']
train_times = [0.1226, 0.1083, 0.1097, 0.1077, 0.1089, 0.1066, 0.1075, 0.1079, 0.1054, 0.1086]
test1_times = [2.9533, 2.6283, 2.6442, 2.6417, 2.6342, 2.6407, 2.6289, 2.6328, 2.6350, 2.6190]
test2_times = [0.5821, 0.5832, 0.5814, 0.5836, 0.5958, 0.5848, 0.5876, 0.5846, 0.5837, 0.5837]

# Plotting
plt.figure(figsize=(10, 6))

bar_height = 0.25
index = np.arange(len(chunks))

plt.barh(index, train_times, bar_height, label='Train', color='black', alpha=0.99)
plt.barh(index + bar_height, test1_times, bar_height, label='Test-1', color='black', alpha=0.66)
plt.barh(index + 2 * bar_height, test2_times, bar_height, label='Test-2', color='black', alpha=0.33)

# Displaying values on the bars
for i, v in enumerate(train_times):
    plt.text(v + 0.01, i - 0.1, str(v), color='black')

for i, v in enumerate(test1_times):
    plt.text(v + 0.01, i + bar_height - 0.1, str(v), color='black')

for i, v in enumerate(test2_times):
    plt.text(v + 0.01, i + 2 * bar_height - 0.1, str(v), color='black')

plt.xlabel('Run Time (hrs)')
#plt.ylabel('Chunk')
plt.title('Comparing Time Requirement for Training and Testing On Chunk Models of AnySoftKeyboard Dataset')
plt.yticks(index + bar_height, chunks)
plt.legend()

plt.tight_layout()
plt.savefig(f'inc_saved_images/compTrainTestFull.png') #Save the image to disk
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x_values = ['chunk-1', 'chunk-2', 'chunk-3', 'chunk-4', 'chunk-5', 'chunk-6', 'chunk-7', 'chunk-8', 'chunk-9', 'chunk-10']
train_time = [441.57, 389.86, 394.86, 387.53, 392.2, 383.86, 386.87, 388.31, 381.26, 390.91]
test1_time = [531.61, 473.04, 475.95, 475.53, 474.15, 475.23, 473.21, 473.90, 474.30, 471.42]
test2_time = [2097.42, 2099.59, 2092.87, 2101.11, 2144.94, 2105.26, 2115.42, 2106.4, 2103.37, 2103.37]

# Set the bar width for better visualization
bar_width = 0.25

# Calculate the x-axis positions for each group
index = np.arange(len(x_values))

# Plotting the results using bar plot
plt.figure(figsize=(12, 6))
plt.bar(index - bar_width, train_time, width=bar_width, label='Training Time')
plt.bar(index, test1_time, width=bar_width, label='Test1 Time')
plt.bar(index + bar_width, test2_time, width=bar_width, label='Test2 Time')

# Adding labels and title
plt.xlabel('Chunk')
plt.ylabel('Time (s)')
plt.title('Experimental Results')
plt.legend()

# Adjusting x-axis labels
plt.xticks(index, x_values)
plt.xticks(rotation=45)

# Show plot
plt.tight_layout()
plt.grid(True)
plt.show()

# %%
#anysoftkeyboard

# Data for the validation phase
validation_data = [
    [0.65, 0.69, 0.56, 0.62, 0.65, 0.31, 0.65, 0.63, 0.63, 0.64, 0.65, 0.64, 0.65, 0.62],
    [0.62, 0.61, 0.7, 0.65, 0.62, 0.25, 0.67, 0.63, 0.67, 0.64, 0.69, 0.63, 0.64, 0.62],
    [0.66, 0.65, 0.69, 0.67, 0.66, 0.31, 0.61, 0.63, 0.53, 0.64, 0.57, 0.66, 0.7, 0.65],
    [0.6, 0.6, 0.64, 0.62, 0.6, 0.21, 0.67, 0.64, 0.59, 0.64, 0.62, 0.64, 0.67, 0.63],
    [0.63, 0.63, 0.61, 0.62, 0.63, 0.25, 0.62, 0.63, 0.64, 0.64, 0.62, 0.64, 0.63, 0.62],
    [0.61, 0.62, 0.58, 0.6, 0.61, 0.23, 0.64, 0.62, 0.62, 0.62, 0.62, 0.64, 0.7, 0.63],
    [0.65, 0.67, 0.61, 0.64, 0.65, 0.3, 0.62, 0.64, 0.61, 0.63, 0.64, 0.67, 0.56, 0.62],
    [0.63, 0.63, 0.63, 0.63, 0.63, 0.26, 0.67, 0.63, 0.63, 0.63, 0.63, 0.63, 0.53, 0.64],
    [0.63, 0.67, 0.53, 0.59, 0.63, 0.27, 0.64, 0.66, 0.54, 0.59, 0.62, 0.64, 0.64, 0.64],
    [0.64, 0.64, 0.64, 0.64, 0.64, 0.28, 0.65, 0.65, 0.61, 0.63, 0.64, 0.64, 0.67, 0.67],
    [0.65, 0.69, 0.57, 0.62, 0.65, 0.31, 0.69, 0.64, 0.63, 0.64, 0.65, 0.63, 0.66, 0.64],
    [0.64, 0.63, 0.66, 0.64, 0.64, 0.27, 0.64, 0.62, 0.64, 0.62, 0.64, 0.64, 0.66, 0.64],
    [0.65, 0.64, 0.7, 0.67, 0.65, 0.3, 0.65, 0.64, 0.65, 0.63, 0.62, 0.67, 0.54, 0.68],
    [0.62, 0.62, 0.65, 0.63, 0.62, 0.24, 0.63, 0.63, 0.62, 0.62, 0.62, 0.63, 0.59, 0.66]
]

# Data for the testing phase
testing_data = [
    [0.62, 0.67, 0.53, 0.59, 0.63, 0.26, 0.64, 0.64, 0.68, 0.66, 0.64, 0.64, 0.67, 0.66],
    [0.64, 0.64, 0.71, 0.67, 0.64, 0.29, 0.64, 0.64, 0.67, 0.65, 0.64, 0.64, 0.65, 0.67],
    [0.64, 0.64, 0.69, 0.66, 0.64, 0.29, 0.64, 0.64, 0.67, 0.65, 0.64, 0.66, 0.66, 0.66],
    [0.64, 0.64, 0.67, 0.65, 0.64, 0.27, 0.64, 0.64, 0.67, 0.66, 0.64, 0.65, 0.66, 0.65],
    [0.64, 0.66, 0.62, 0.64, 0.64, 0.28, 0.63, 0.64, 0.62, 0.64, 0.62, 0.63, 0.65, 0.64],
    [0.63, 0.66, 0.6, 0.63, 0.64, 0.27, 0.66, 0.66, 0.64, 0.64, 0.64, 0.66, 0.63, 0.66],
    [0.62, 0.64, 0.61, 0.62, 0.62, 0.25, 0.6, 0.62, 0.62, 0.63, 0.61, 0.65, 0.64, 0.65],
    [0.63, 0.64, 0.64, 0.64, 0.63, 0.25, 0.63, 0.64, 0.65, 0.64, 0.63, 0.64, 0.67, 0.64],
    [0.62, 0.66, 0.54, 0.59, 0.62, 0.25, 0.64, 0.66, 0.62, 0.62, 0.62, 0.64, 0.66, 0.65],
    [0.64, 0.65, 0.61, 0.63, 0.64, 0.27, 0.59, 0.65, 0.61, 0.63, 0.61, 0.64, 0.65, 0.63],
    [0.64, 0.67, 0.56, 0.61, 0.64, 0.28, 0.62, 0.64, 0.61, 0.63, 0.62, 0.63, 0.66, 0.65],
    [0.63, 0.63, 0.66, 0.65, 0.63, 0.26, 0.64, 0.64, 0.66, 0.65, 0.63, 0.65, 0.64, 0.65],
    [0.64, 0.64, 0.68, 0.66, 0.64, 0.28, 0.64, 0.64, 0.67, 0.66, 0.64, 0.66, 0.65, 0.66],
    [0.64, 0.64, 0.67, 0.66, 0.64, 0.28, 0.64, 0.64, 0.67, 0.66, 0.64, 0.66, 0.65, 0.66]
]

# Labels for each metric
labels = ['Accuracy', 'Precision', 'Recall', 'AnySoftK', 'ROC-AUC', 'MCC']

# Plotting
fig, ax = plt.subplots(nrows=2, ncols=6, figsize=(18, 8))
for i in range(6):
    ax[0,i].plot(validation_data[i], label='Validation', marker='o')
    ax[0,i].plot(testing_data[i], label='Testing', marker='x')
    ax[0,i].set_title(labels[i])
    ax[0,i].legend()
    ax[0,i].set_xticks(range(14))
    ax[0,i].set_xticklabels(range(1, 15))
    ax[0,i].grid(True)
    ax[1,i].boxplot([validation_data[i], testing_data[i]], labels=['Validation', 'Testing'])
    ax[1,i].set_title(labels[i] + ' Boxplot')
    ax[1,i].grid(True)
plt.tight_layout()
plt.show()

# %%
#facebook

# Data for the validation phase
validation_data = [
    [0.81, 0.8, 0.8, 0.82, 0.81, 0.8, 0.8, 0.56],
    [0.79, 0.78, 0.78, 0.78, 0.77, 0.78, 0.82, 0.53],
    [0.84, 0.83, 0.83, 0.88, 0.86, 0.84, 0.77, 0.87],
    [0.81, 0.81, 0.8, 0.83, 0.82, 0.81, 0.79, 0.66],
    [0.81, 0.8, 0.8, 0.83, 0.81, 0.8, 0.8, 0.56],
    [0.63, 0.61, 0.61, 0.65, 0.62, 0.61, 0.61, 0.16]
]

# Data for the testing phase
testing_data = [
    [0.8, 0.77, 0.77, 0.79, 0.78, 0.78, 0.77, 0.57],
    [0.78, 0.77, 0.75, 0.77, 0.75, 0.76, 0.77, 0.55],
    [0.85, 0.77, 0.8, 0.82, 0.84, 0.81, 0.77, 0.87],
    [0.81, 0.77, 0.78, 0.79, 0.79, 0.78, 0.77, 0.67],
    [0.8, 0.77, 0.77, 0.79, 0.78, 0.78, 0.77, 0.57],
    [0.61, 0.53, 0.53, 0.58, 0.56, 0.55, 0.54, 0.17]
]

# Labels for each metric
labels = ['Accuracy', 'Precision', 'Recall', 'Facebook', 'ROC-AUC', 'MCC']

# Plotting
fig, ax = plt.subplots(nrows=2, ncols=6, figsize=(18, 8))
for i in range(6):
    ax[0,i].plot(validation_data[i], label='Validation', marker='o')
    ax[0,i].plot(testing_data[i], label='Testing', marker='x')
    ax[0,i].set_title(labels[i])
    ax[0,i].legend()
    ax[0,i].set_xticks(range(8))
    ax[0,i].set_xticklabels(range(1, 9))
    ax[0,i].grid(True)
    ax[1,i].boxplot([validation_data[i], testing_data[i]], labels=['Validation', 'Testing'])
    ax[1,i].set_title(labels[i] + ' Boxplot')
    ax[1,i].grid(True)
plt.tight_layout()
plt.show()

# %%
#kiwis

# Data for the validation phase
validation_data = [
    [0.62, 0.68, 0.65, 0.61, 0.65, 0.65, 0.62, 0.63, 0.66, 0.62],
    [0.65, 0.68, 0.66, 0.61, 0.67, 0.66, 0.62, 0.65, 0.69, 0.64],
    [0.54, 0.7, 0.63, 0.64, 0.6, 0.65, 0.64, 0.57, 0.58, 0.55],
    [0.59, 0.69, 0.64, 0.62, 0.64, 0.65, 0.63, 0.61, 0.63, 0.59],
    [0.62, 0.68, 0.65, 0.61, 0.65, 0.65, 0.62, 0.63, 0.66, 0.62],
    [0.25, 0.37, 0.29, 0.21, 0.3, 0.3, 0.24, 0.26, 0.32, 0.24]
]

# Data for the testing phase
testing_data = [
    [0.64, 0.64, 0.66, 0.64, 0.63, 0.62, 0.65, 0.65, 0.66, 0.63],
    [0.64, 0.62, 0.64, 0.62, 0.62, 0.6, 0.63, 0.64, 0.67, 0.63],
    [0.59, 0.66, 0.66, 0.66, 0.62, 0.66, 0.65, 0.65, 0.58, 0.56],
    [0.62, 0.64, 0.65, 0.64, 0.62, 0.63, 0.64, 0.64, 0.62, 0.59],
    [0.64, 0.64, 0.66, 0.64, 0.63, 0.62, 0.65, 0.65, 0.65, 0.63],
    [0.29, 0.28, 0.31, 0.28, 0.27, 0.25, 0.29, 0.3, 0.31, 0.25]
]

# Labels for each metric
labels = ['Accuracy', 'Precision', 'Recall', 'Kiwis', 'ROC-AUC', 'MCC']

# Plotting
fig, ax = plt.subplots(nrows=2, ncols=6, figsize=(18, 8))
for i in range(6):
    ax[0,i].plot(validation_data[i], label='Validation', marker='o')
    ax[0,i].plot(testing_data[i], label='Testing', marker='x')
    ax[0,i].set_title(labels[i])
    ax[0,i].legend()
    ax[0,i].set_xticks(range(10))
    ax[0,i].set_xticklabels(range(1, 11))
    ax[0,i].grid(True)
    ax[1,i].boxplot([validation_data[i], testing_data[i]], labels=['Validation', 'Testing'])
    ax[1,i].set_title(labels[i] + ' Boxplot')
    ax[1,i].grid(True)
plt.tight_layout()
plt.show()

# %%
#jm1
import matplotlib.pyplot as plt

# Data for the validation phase
validation_data = [
    [0.57, 0.58, 0.58, 0.58, 0.55, 0.62, 0.58],
    [0.57, 0.68, 0.59, 0.56, 0.54, 0.69, 0.55],
    [0.58, 0.31, 0.47, 0.77, 0.69, 0.43, 0.9],
    [0.57, 0.43, 0.53, 0.65, 0.61, 0.53, 0.68],
    [0.57, 0.58, 0.58, 0.58, 0.55, 0.62, 0.58],
    [0.15, 0.2, 0.16, 0.18, 0.11, 0.26, 0.22]
]

# Data for the testing phase
testing_data = [
    [0.54, 0.53, 0.5, 0.53, 0.56, 0.53, 0.53],
    [0.56, 0.6, 0.51, 0.53, 0.56, 0.57, 0.52],
    [0.51, 0.24, 0.41, 0.73, 0.68, 0.33, 0.9],
    [0.53, 0.34, 0.46, 0.62, 0.61, 0.42, 0.66],
    [0.54, 0.54, 0.5, 0.53, 0.56, 0.53, 0.52],
    [0.09, 0.09, 0.01, 0.06, 0.12, 0.07, 0.06]
]

# Labels for each metric
labels = ['Accuracy', 'Precision', 'Recall', 'Jm1', 'ROC-AUC', 'MCC']

# Plotting
fig, ax = plt.subplots(nrows=2, ncols=6, figsize=(18, 8))
for i in range(6):
    ax[0,i].plot(validation_data[i], label='Validation', marker='o')
    ax[0,i].plot(testing_data[i], label='Testing', marker='x')
    ax[0,i].set_title(labels[i])
    ax[0,i].legend()
    ax[0,i].set_xticks(range(7))
    ax[0,i].set_xticklabels(range(1, 8))
    ax[0,i].grid(True)
    ax[1,i].boxplot([validation_data[i], testing_data[i]], labels=['Validation', 'Testing'])
    ax[1,i].set_title(labels[i] + ' Boxplot')
    ax[1,i].grid(True)
plt.tight_layout()
plt.show()
